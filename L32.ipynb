# %% [markdown]
# # 操作文件和目录

# %% [markdown]
# 如果我们要操作文件、目录，可以在命令行下面输入操作系统提供的各种命令来完成。比如dir、cp等命令。
#
# 如果要在Python程序中执行这些目录和文件的操作怎么办？其实操作系统提供的命令只是简单地调用了操作系统提供的接口函数，Python内置的os模块也可以直接调用操作系统提供的接口函数。
#
# 打开Python交互式命令行，我们来看看如何使用os模块的基本功能：

# %%
import os

# %%
os.name
# Out:
# 'posix'

# %% [markdown]
# 如果是posix，说明系统是Linux、Unix或Mac OS X，如果是nt，就是Windows系统。
#
# 要获取详细的系统信息，可以调用uname()函数：

# %%
os.uname()
# Out:
# posix.uname_result(sysname='Darwin', nodename='GTX1080-iMac.local', release='17.6.0', version='Darwin Kernel Version 17.6.0: Tue May  8 15:22:16 PDT 2018; root:xnu-4570.61.1~1/RELEASE_X86_64', machine='x86_64')

# %% [markdown]
# 注意uname()函数在Windows上不提供，也就是说，os模块的某些函数是跟操作系统相关的

# %% [markdown]
# ## 环境变量
#
# 在操作系统中定义的环境变量，全部保存在os.environ这个变量中，可以直接查看：

# %%
os.environ
# Out:
# environ({'TERM_PROGRAM': 'Apple_Terminal', 'ANDROID_HOME': '/Volumes/Data/NVPACK/android-sdk-macosx', 'SHELL': '/bin/bash', 'TERM': 'xterm-color', 'TMPDIR': '/var/folders/5x/l086nwcj45sc8_391stzmxbw0000gn/T/', 'GRADLE_HOME': '/Volumes/Data/NVPACK/gradle-4.1', 'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.kYxA0wQGxE/Render', 'TERM_PROGRAM_VERSION': '404', 'OLDPWD': '/Users/zhipingxu', 'NVPACK_NDK_TOOL_VERSION': '4.9', 'TERM_SESSION_ID': '5676CDA6-6656-4E66-81EA-FF00D1C81797', 'NVPACK_ROOT': '/Volumes/Data/NVPACK', 'ANT_HOME': '/Volumes/Data/NVPACK/apache-ant-1.8.2', 'CUDA_HOME': '/usr/local/cuda', 'USER': 'zhipingxu', 'NDKROOT': '/Volumes/Data/NVPACK/android-ndk-r15c', 'NVPACK_NDK_VERSION': 'android-ndk-r15c', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.u1129bGwow/Listeners', 'PATH': '/Users/zhipingxu/anaconda3/bin:/usr/local/opt/openssl/bin:/Users/zhipingxu/anaconda3/bin:/usr/local/sbin:/usr/local/cuda/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/TeX/texbin:/usr/local/share/dotnet:/opt/X11/bin:/Library/Frameworks/Mono.framework/Versions/Current/Commands:/Applications/Xamarin Workbooks.app/Contents/SharedSupport/path-bin:/Volumes/Data/NVPACK/android-ndk-r15c:/Volumes/Data/NVPACK/apache-ant-1.8.2/bin:/Volumes/Data/NVPACK/gradle-4.1/bin:/Volumes/Data/NVPACK/android-sdk-macosx/tools:/Volumes/Data/NVPACK/android-sdk-macosx/platform-tools:/Volumes/Data/NVPACK/android-sdk-macosx/build-tools:/Volumes/Data/NVPACK/android-sdk-macosx/extras/android/support', 'PWD': '/Users/zhipingxu/python_learning', 'LANG': 'zh_CN.UTF-8', 'XPC_FLAGS': '0x0', 'XPC_SERVICE_NAME': '0', 'SHLVL': '1', 'HOME': '/Users/zhipingxu', 'DYLD_LIBRARY_PATH': ':/usr/local/cuda/lib:/usr/local/cuda/lib:/usr/local/Cellar/gmp/6.1.2_1/lib', 'LOGNAME': 'zhipingxu', 'DISPLAY': '/private/tmp/com.apple.launchd.JTA034dRMA/org.macosforge.xquartz:0', 'NDK_ROOT': '/Volumes/Data/NVPACK/android-ndk-r15c', '_': '/Users/zhipingxu/anaconda3/bin/jupyter', '__CF_USER_TEXT_ENCODING': '0x1F5:0x19:0x34', 'JPY_PARENT_PID': '1170', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://ipykernel.pylab.backend_inline'})

# %% [markdown]
# 要获取某个环境变量的值，可以调用os.environ.get('key')：

# %%
os.environ.get('PATH')
# Out:
# '/Users/zhipingxu/anaconda3/bin:/usr/local/opt/openssl/bin:/Users/zhipingxu/anaconda3/bin:/usr/local/sbin:/usr/local/cuda/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/TeX/texbin:/usr/local/share/dotnet:/opt/X11/bin:/Library/Frameworks/Mono.framework/Versions/Current/Commands:/Applications/Xamarin Workbooks.app/Contents/SharedSupport/path-bin:/Volumes/Data/NVPACK/android-ndk-r15c:/Volumes/Data/NVPACK/apache-ant-1.8.2/bin:/Volumes/Data/NVPACK/gradle-4.1/bin:/Volumes/Data/NVPACK/android-sdk-macosx/tools:/Volumes/Data/NVPACK/android-sdk-macosx/platform-tools:/Volumes/Data/NVPACK/android-sdk-macosx/build-tools:/Volumes/Data/NVPACK/android-sdk-macosx/extras/android/support'

# %%
os.environ.get('x', 'default')
# Out:
# 'default'

# %% [markdown]
# ## 操作文件和目录
#
# 操作文件和目录的函数一部分放在os模块中，一部分放在os.path模块中，这一点要注意一下。查看、创建和删除目录可以这么调用：

# %%
# 查看当前目录的绝对路径:
os.path.abspath('.')
# Out:
# '/Users/zhipingxu/python_learning'

# %%
# 在某个目录下创建一个新目录，首先把新目录的完整路径表示出来:
os.path.join('/Users/zhipingxu', 'testdir')
# Out:
# '/Users/zhipingxu/testdir'

# %%
# 然后创建一个目录:
os.mkdir('/Users/zhipingxu/testdir')

# %%
# 删掉一个目录:
os.rmdir('/Users/zhipingxu/testdir')

# %% [markdown]
# 把两个路径合成一个时，不要直接拼字符串，而要通过os.path.join()函数，这样可以正确处理不同操作系统的路径分隔符。在Linux/Unix/Mac下，os.path.join()返回这样的字符串：
# ```
# part-1/part-2
# ```
# 而Windows下会返回这样的字符串：
# ```
# part-1\part-2
# ```
# 同样的道理，要拆分路径时，也不要直接去拆字符串，而要通过os.path.split()函数，这样可以把一个路径拆分为两部分，后一部分总是最后级别的目录或文件名：

# %%
os.path.split('/Users/zhipingxu/testdir/file.txt')
# Out:
# ('/Users/zhipingxu/testdir', 'file.txt')

# %% [markdown]
# os.path.splitext()可以直接让你得到文件扩展名，很多时候非常方便：

# %%
os.path.splitext('/path/to/file.txt')
# Out:
# ('/path/to/file', '.txt')

# %% [markdown]
# 这些合并、拆分路径的函数并不要求目录和文件要真实存在，它们只对字符串进行操作。
#
# 文件操作使用下面的函数。假定当前目录下有一个test.txt文件：

# %% [markdown]
# ```
# # 对文件重命名:
# >>> os.rename('test.txt', 'test.py')
# # 删掉文件:
# >>> os.remove('test.py')
# ```
#
# 但是复制文件的函数居然在os模块中不存在！原因是复制文件并非由操作系统提供的系统调用。理论上讲，我们通过上一节的读写文件可以完成文件复制，只不过要多写很多代码。
#
# 幸运的是shutil模块提供了copyfile()的函数，你还可以在shutil模块中找到很多实用函数，它们可以看做是os模块的补充。
#
# 最后看看如何利用Python的特性来过滤文件。比如我们要列出当前目录下的所有目录，只需要一行代码：

# %%
[x for x in os.listdir('.') if os.path.isdir(x)]
# Out:
# ['.ipynb_checkpoints']

# %% [markdown]
# 要列出所有的.py文件，也只需一行代码：

# %%
[x for x in os.listdir('.') if os.path.isfile(x) and os.path.splitext(x)[1]=='.py']
# Out:
# []

# %% [markdown]
# 是不是非常简洁？
#
# ## 小结
#
# Python的os模块封装了操作系统的目录和文件操作，要注意这些函数有的在os模块中，有的在os.path模块中。
#
# ## 练习
#
# 利用os模块编写一个能实现dir -l输出的程序。
#
# 编写一个程序，能在当前目录以及当前目录的所有子目录下查找文件名包含指定字符串的文件，并打印出相对路径。
